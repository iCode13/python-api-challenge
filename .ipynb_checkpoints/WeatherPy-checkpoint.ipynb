# %% [markdown]
# # WeatherPy

# %%
# Dependencies and setup.

# %matplotlib inline

import os
import pandas as pd
import numpy as np
import requests
import matplotlib.pyplot as plt
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Import citipy to get cities based on latitude and longitude
from citipy import citipy

# Output file (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
# Weather API key.
weather_api_key
# Out:
# 'a6a71f9604b1a38f6deb7dbe79c0c329'

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities.
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Import citipy to get cities based on latitude and longitude
from citipy import citipy

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
         cities.append(city)

# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 642

# %%
print(city)
# Out:
# santa cruz

# %% [markdown]
# ## Perform API Calls

# %%
new_cities = []
cloudiness = []
country = []
date = []
humidity = []
temp = []
lat = []
lng = []
wind = []

# %%
# Starting URL for Weather Map API Call.

record_counter = 0
set_counter = 0

url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key 

print('------------------------')
print('Beginning Data Retrieval')
print('------------------------')

for city in cities:
    query_url = url + "&q=" + city
    # Get weather data
    response = requests.get(query_url).json()
    if record_counter < 50:
        record_counter += 1
    else:
        set_counter += 1
        record_counter = 0

    print('Processing record {} of set {} | {}'.format(record_counter, set_counter, city))
    try:
        cloudiness.append(response['clouds']['all'])
        country.append(response['sys']['country'])
        date.append(response['dt'])
        humidity.append(response['main']['humidity'])
        temp.append(response['main']['temp_max'])
        lat.append(response['coord']['lat'])
        lng.append(response['coord']['lon'])
        wind.append(response['wind']['speed'])
        new_cities.append(city)
    except:
        print("City not found!")
        pass

print('-------------------------')
print('Data Retrieval Complete')
print('-------------------------')
# Out:
# ------------------------
# Beginning Data Retrieval
# ------------------------
# Processing record 1 of set 0 | ipixuna
# Processing record 2 of set 0 | liverpool
# Processing record 3 of set 0 | sentyabrskiy
# City not found!
# Processing record 4 of set 0 | vaini
# Processing record 5 of set 0 | puerto ayora
# Processing record 6 of set 0 | avarua
# Processing record 7 of set 0 | busselton
# Processing record 8 of set 0 | rikitea
# Processing record 9 of set 0 | bluff
# Processing record 10 of set 0 | port blair
# Processing record 11 of set 0 | isla mujeres
# Processing record 12 of set 0 | kapaa
# Processing record 13 of set 0 | velikiy ustyug
# Processing record 14 of set 0 | ushuaia
# Processing record 15 of set 0 | padang
# Processing record 16 of set 0 | gamba
# Processing record 17 of set 0 | chokurdakh
# Processing record 18 of set 0 | barrow
# Processing record 19 of set 0 | arraial do cabo
# Processing record 20 of set 0 | souillac
# Processing record 21 of set 0 | belushya guba
# City not found!
# Processing record 22 of set 0 | cidreira
# Processing record 23 of set 0 | sao jose de piranhas
# Processing record 24 of set 0 | coahuayana
# Processing record 25 of set 0 | punta arenas
# Processing record 26 of set 0 | palmer
# Processing record 27 of set 0 | dikson
# Processing record 28 of set 0 | saint george
# Processing record 29 of set 0 | mataura
# Processing record 30 of set 0 | cherskiy
# Processing record 31 of set 0 | nioro
# Processing record 32 of set 0 | lexington park
# Processing record 33 of set 0 | hilo
# Processing record 34 of set 0 | teacapan
# Processing record 35 of set 0 | inhambane
# Processing record 36 of set 0 | hualmay
# Processing record 37 of set 0 | codrington
# Processing record 38 of set 0 | hermanus
# Processing record 39 of set 0 | airai
# Processing record 40 of set 0 | hofn
# Processing record 41 of set 0 | kruisfontein
# Processing record 42 of set 0 | jamestown
# Processing record 43 of set 0 | butaritari
# Processing record 44 of set 0 | albany
# Processing record 45 of set 0 | east london
# Processing record 46 of set 0 | atuona
# Processing record 47 of set 0 | provideniya
# Processing record 48 of set 0 | kahului
# Processing record 49 of set 0 | rohnert park
# Processing record 50 of set 0 | nizhneyansk
# City not found!
# Processing record 0 of set 1 | constitucion
# Processing record 1 of set 1 | linqu
# Processing record 2 of set 1 | gat
# Processing record 3 of set 1 | apatity
# Processing record 4 of set 1 | hithadhoo
# Processing record 5 of set 1 | lagoa
# Processing record 6 of set 1 | ayer itam
# City not found!
# Processing record 7 of set 1 | consolacion del sur
# Processing record 8 of set 1 | evensk
# Processing record 9 of set 1 | najran
# Processing record 10 of set 1 | castro
# Processing record 11 of set 1 | ribeira grande
# Processing record 12 of set 1 | yining
# Processing record 13 of set 1 | gorele
# Processing record 14 of set 1 | launceston
# Processing record 15 of set 1 | laguna
# Processing record 16 of set 1 | nanortalik
# Processing record 17 of set 1 | toyooka
# Processing record 18 of set 1 | gainesville
# Processing record 19 of set 1 | hobart
# Processing record 20 of set 1 | tsihombe
# City not found!
# Processing record 21 of set 1 | edson
# Processing record 22 of set 1 | faanui
# Processing record 23 of set 1 | sorvag
# City not found!
# Processing record 24 of set 1 | ponta do sol
# Processing record 25 of set 1 | kibondo
# Processing record 26 of set 1 | luganville
# Processing record 27 of set 1 | nam tha
# City not found!
# Processing record 28 of set 1 | rawson
# Processing record 29 of set 1 | khatanga
# Processing record 30 of set 1 | saleaula
# City not found!
# Processing record 31 of set 1 | pereleshinskiy
# Processing record 32 of set 1 | zubova polyana
# Processing record 33 of set 1 | sola
# Processing record 34 of set 1 | moramanga
# Processing record 35 of set 1 | eureka
# Processing record 36 of set 1 | cozumel
# Processing record 37 of set 1 | san patricio
# Processing record 38 of set 1 | avera
# Processing record 39 of set 1 | victoria
# Processing record 40 of set 1 | tres arroyos
# Processing record 41 of set 1 | pisco
# Processing record 42 of set 1 | bo rai
# Processing record 43 of set 1 | georgetown
# Processing record 44 of set 1 | manzhouli
# Processing record 45 of set 1 | fortuna
# Processing record 46 of set 1 | andevoranto
# City not found!
# Processing record 47 of set 1 | lumeje
# Processing record 48 of set 1 | tara
# Processing record 49 of set 1 | saumur
# Processing record 50 of set 1 | myslenice
# Processing record 0 of set 2 | bethel
# Processing record 1 of set 2 | darhan
# Processing record 2 of set 2 | viedma
# Processing record 3 of set 2 | singaparna
# Processing record 4 of set 2 | falealupo
# City not found!
# Processing record 5 of set 2 | chase
# Processing record 6 of set 2 | port alfred
# Processing record 7 of set 2 | honningsvag
# Processing record 8 of set 2 | coruripe
# Processing record 9 of set 2 | longyearbyen
# Processing record 10 of set 2 | lagos
# Processing record 11 of set 2 | taolanaro
# City not found!
# Processing record 12 of set 2 | angoche
# Processing record 13 of set 2 | itarema
# Processing record 14 of set 2 | ilulissat
# Processing record 15 of set 2 | nikolskoye
# Processing record 16 of set 2 | beisfjord
# Processing record 17 of set 2 | excelsior springs
# Processing record 18 of set 2 | charagua
# Processing record 19 of set 2 | caxito
# Processing record 20 of set 2 | tura
# Processing record 21 of set 2 | nago
# Processing record 22 of set 2 | cap malheureux
# Processing record 23 of set 2 | tuktoyaktuk
# Processing record 24 of set 2 | bintulu
# Processing record 25 of set 2 | maham
# Processing record 26 of set 2 | uchiza
# Processing record 27 of set 2 | hami
# Processing record 28 of set 2 | barentsburg
# City not found!
# Processing record 29 of set 2 | coihaique
# Processing record 30 of set 2 | marabba
# Processing record 31 of set 2 | gander
# Processing record 32 of set 2 | bredasdorp
# Processing record 33 of set 2 | popondetta
# Processing record 34 of set 2 | cape town
# Processing record 35 of set 2 | goderich
# Processing record 36 of set 2 | upernavik
# Processing record 37 of set 2 | narsaq
# Processing record 38 of set 2 | neiafu
# Processing record 39 of set 2 | kamaishi
# Processing record 40 of set 2 | mantua
# Processing record 41 of set 2 | aklavik
# Processing record 42 of set 2 | norman wells
# Processing record 43 of set 2 | trelew
# Processing record 44 of set 2 | tumannyy
# City not found!
# Processing record 45 of set 2 | geraldton
# Processing record 46 of set 2 | vieques
# Processing record 47 of set 2 | severo-kurilsk
# Processing record 48 of set 2 | buala
# Processing record 49 of set 2 | te anau
# Processing record 50 of set 2 | makakilo city
# Processing record 0 of set 3 | dingle
# Processing record 1 of set 3 | amderma
# City not found!
# Processing record 2 of set 3 | touros
# Processing record 3 of set 3 | saint anthony
# Processing record 4 of set 3 | kavieng
# Processing record 5 of set 3 | acarau
# Processing record 6 of set 3 | kralendijk
# Processing record 7 of set 3 | port macquarie
# Processing record 8 of set 3 | carnarvon
# Processing record 9 of set 3 | lorengau
# Processing record 10 of set 3 | dharchula
# Processing record 11 of set 3 | thompson
# Processing record 12 of set 3 | cayenne
# Processing record 13 of set 3 | college
# Processing record 14 of set 3 | illoqqortoormiut
# City not found!
# Processing record 15 of set 3 | gazanjyk
# Processing record 16 of set 3 | richards bay
# Processing record 17 of set 3 | phalodi
# Processing record 18 of set 3 | attawapiskat
# City not found!
# Processing record 19 of set 3 | santa luzia
# Processing record 20 of set 3 | kasempa
# Processing record 21 of set 3 | harrisonburg
# Processing record 22 of set 3 | okhotsk
# Processing record 23 of set 3 | sao jose da coroa grande
# Processing record 24 of set 3 | smolenka
# Processing record 25 of set 3 | hun
# Processing record 26 of set 3 | mahebourg
# Processing record 27 of set 3 | san pedro de macoris
# Processing record 28 of set 3 | sept-iles
# Processing record 29 of set 3 | tasiilaq
# Processing record 30 of set 3 | sabha
# Processing record 31 of set 3 | puerto del rosario
# Processing record 32 of set 3 | sitka
# Processing record 33 of set 3 | namibe
# Processing record 34 of set 3 | mar del plata
# Processing record 35 of set 3 | general roca
# Processing record 36 of set 3 | tiksi
# Processing record 37 of set 3 | myskhako
# Processing record 38 of set 3 | cabo san lucas
# Processing record 39 of set 3 | hambantota
# Processing record 40 of set 3 | alofi
# Processing record 41 of set 3 | warmbad
# Processing record 42 of set 3 | zhangjiakou
# Processing record 43 of set 3 | gumla
# Processing record 44 of set 3 | miyako
# Processing record 45 of set 3 | pindiga
# Processing record 46 of set 3 | raga
# Processing record 47 of set 3 | kaitangata
# Processing record 48 of set 3 | isangel
# Processing record 49 of set 3 | sao joao da barra
# Processing record 50 of set 3 | samusu
# City not found!
# Processing record 0 of set 4 | coquimbo
# Processing record 1 of set 4 | saskylakh
# Processing record 2 of set 4 | ruthen
# Processing record 3 of set 4 | stepnyak
# Processing record 4 of set 4 | saint-philippe
# Processing record 5 of set 4 | feldkirchen
# Processing record 6 of set 4 | vardo
# Processing record 7 of set 4 | ohara
# Processing record 8 of set 4 | vilaka
# City not found!
# Processing record 9 of set 4 | casablanca
# Processing record 10 of set 4 | sychevka
# Processing record 11 of set 4 | manaure
# Processing record 12 of set 4 | lavrentiya
# Processing record 13 of set 4 | ginda
# Processing record 14 of set 4 | mahajanga
# Processing record 15 of set 4 | ndele
# Processing record 16 of set 4 | yellowknife
# Processing record 17 of set 4 | road town
# Processing record 18 of set 4 | chimbote
# Processing record 19 of set 4 | ust-tsilma
# Processing record 20 of set 4 | sinjar
# Processing record 21 of set 4 | flin flon
# Processing record 22 of set 4 | new norfolk
# Processing record 23 of set 4 | wageningen
# Processing record 24 of set 4 | gitega
# Processing record 25 of set 4 | lata
# Processing record 26 of set 4 | moose factory
# Processing record 27 of set 4 | grand river south east
# City not found!
# Processing record 28 of set 4 | rodrigues alves
# Processing record 29 of set 4 | katsuura
# Processing record 30 of set 4 | praia da vitoria
# Processing record 31 of set 4 | katobu
# Processing record 32 of set 4 | los llanos de aridane
# Processing record 33 of set 4 | falkoping
# City not found!
# Processing record 34 of set 4 | mykolayivka
# Processing record 35 of set 4 | daxian
# City not found!
# Processing record 36 of set 4 | turukhansk
# Processing record 37 of set 4 | virginia beach
# Processing record 38 of set 4 | nusaybin
# Processing record 39 of set 4 | yanji
# Processing record 40 of set 4 | nouakchott
# Processing record 41 of set 4 | achisay
# City not found!
# Processing record 42 of set 4 | salalah
# Processing record 43 of set 4 | sines
# Processing record 44 of set 4 | poya
# Processing record 45 of set 4 | collie
# Processing record 46 of set 4 | alyangula
# Processing record 47 of set 4 | bonavista
# Processing record 48 of set 4 | urdzhar
# City not found!
# Processing record 49 of set 4 | wingham
# Processing record 50 of set 4 | kokkola
# Processing record 0 of set 5 | yangcun
# Processing record 1 of set 5 | talnakh
# Processing record 2 of set 5 | lebu
# Processing record 3 of set 5 | paamiut
# Processing record 4 of set 5 | bambous virieux
# Processing record 5 of set 5 | kanigoro
# Processing record 6 of set 5 | dzilam gonzalez
# Processing record 7 of set 5 | turayf
# Processing record 8 of set 5 | milkovo
# Processing record 9 of set 5 | pueblo
# Processing record 10 of set 5 | borgarnes
# Processing record 11 of set 5 | srednekolymsk
# Processing record 12 of set 5 | mys shmidta
# City not found!
# Processing record 13 of set 5 | semnan
# Processing record 14 of set 5 | terney
# Processing record 15 of set 5 | torbay
# Processing record 16 of set 5 | mergui
# City not found!
# Processing record 17 of set 5 | brae
# Processing record 18 of set 5 | mangalia
# Processing record 19 of set 5 | toliary
# City not found!
# Processing record 20 of set 5 | esperance
# Processing record 21 of set 5 | beringovskiy
# Processing record 22 of set 5 | port lincoln
# Processing record 23 of set 5 | nakusp
# Processing record 24 of set 5 | novaya lyada
# Processing record 25 of set 5 | asau
# Processing record 26 of set 5 | candawaga
# City not found!
# Processing record 27 of set 5 | petropavlovsk-kamchatskiy
# Processing record 28 of set 5 | nyaunglebin
# Processing record 29 of set 5 | altar
# Processing record 30 of set 5 | pacasmayo
# Processing record 31 of set 5 | mount gambier
# Processing record 32 of set 5 | banmo
# City not found!
# Processing record 33 of set 5 | maridi
# Processing record 34 of set 5 | san fernando
# Processing record 35 of set 5 | copiapo
# Processing record 36 of set 5 | iqaluit
# Processing record 37 of set 5 | muros
# Processing record 38 of set 5 | tessalit
# Processing record 39 of set 5 | huarmey
# Processing record 40 of set 5 | takoradi
# Processing record 41 of set 5 | ruthin
# Processing record 42 of set 5 | fort nelson
# Processing record 43 of set 5 | marcona
# City not found!
# Processing record 44 of set 5 | jupiter
# Processing record 45 of set 5 | saldanha
# Processing record 46 of set 5 | victor harbor
# Processing record 47 of set 5 | grand centre
# City not found!
# Processing record 48 of set 5 | mogochin
# City not found!
# Processing record 49 of set 5 | kavaratti
# Processing record 50 of set 5 | praya
# Processing record 0 of set 6 | tselinnoye
# Processing record 1 of set 6 | butajira
# Processing record 2 of set 6 | port shepstone
# Processing record 3 of set 6 | phan thiet
# Processing record 4 of set 6 | san cristobal
# Processing record 5 of set 6 | wenatchee
# Processing record 6 of set 6 | cascas
# Processing record 7 of set 6 | sungai petani
# Processing record 8 of set 6 | beawar
# Processing record 9 of set 6 | nairn
# Processing record 10 of set 6 | binghamton
# Processing record 11 of set 6 | les ponts-de-ce
# Processing record 12 of set 6 | aquiraz
# Processing record 13 of set 6 | chuy
# Processing record 14 of set 6 | agadez
# Processing record 15 of set 6 | cam pha
# City not found!
# Processing record 16 of set 6 | sorland
# Processing record 17 of set 6 | balikpapan
# Processing record 18 of set 6 | sembakung
# Processing record 19 of set 6 | ashland
# Processing record 20 of set 6 | carnduff
# Processing record 21 of set 6 | vestmanna
# Processing record 22 of set 6 | auki
# Processing record 23 of set 6 | quiruvilca
# Processing record 24 of set 6 | atar
# Processing record 25 of set 6 | tsabong
# Processing record 26 of set 6 | stromness
# Processing record 27 of set 6 | abrau-dyurso
# Processing record 28 of set 6 | vila velha
# Processing record 29 of set 6 | sao filipe
# Processing record 30 of set 6 | port elizabeth
# Processing record 31 of set 6 | tigil
# Processing record 32 of set 6 | dakar
# Processing record 33 of set 6 | zaozhuang
# Processing record 34 of set 6 | seoul
# Processing record 35 of set 6 | panaba
# Processing record 36 of set 6 | cururupu
# Processing record 37 of set 6 | arica
# Processing record 38 of set 6 | derzhavinsk
# Processing record 39 of set 6 | hobyo
# Processing record 40 of set 6 | kudahuvadhoo
# Processing record 41 of set 6 | skalistyy
# City not found!
# Processing record 42 of set 6 | janauba
# Processing record 43 of set 6 | huanren
# Processing record 44 of set 6 | mersing
# Processing record 45 of set 6 | klaksvik
# Processing record 46 of set 6 | kongolo
# Processing record 47 of set 6 | siilinjarvi
# Processing record 48 of set 6 | glasgow
# Processing record 49 of set 6 | naron
# Processing record 50 of set 6 | xining
# Processing record 0 of set 7 | matara
# Processing record 1 of set 7 | saeby
# Processing record 2 of set 7 | rio gallegos
# Processing record 3 of set 7 | aswan
# Processing record 4 of set 7 | paragominas
# Processing record 5 of set 7 | vaitape
# Processing record 6 of set 7 | umm kaddadah
# Processing record 7 of set 7 | fuerte olimpo
# Processing record 8 of set 7 | bozdar
# Processing record 9 of set 7 | shingu
# Processing record 10 of set 7 | kalmeshwar
# Processing record 11 of set 7 | falam
# Processing record 12 of set 7 | vao
# Processing record 13 of set 7 | nipawin
# Processing record 14 of set 7 | haines junction
# Processing record 15 of set 7 | gorey
# Processing record 16 of set 7 | kotaparh
# Processing record 17 of set 7 | umm durman
# City not found!
# Processing record 18 of set 7 | roebourne
# Processing record 19 of set 7 | mugla
# Processing record 20 of set 7 | petropolis
# Processing record 21 of set 7 | xuddur
# Processing record 22 of set 7 | juifang
# City not found!
# Processing record 23 of set 7 | atbasar
# Processing record 24 of set 7 | lazaro cardenas
# Processing record 25 of set 7 | mehamn
# Processing record 26 of set 7 | giresun
# Processing record 27 of set 7 | nome
# Processing record 28 of set 7 | ixtapa
# Processing record 29 of set 7 | jiazi
# Processing record 30 of set 7 | zelenoborskiy
# Processing record 31 of set 7 | kletskaya
# Processing record 32 of set 7 | pevek
# Processing record 33 of set 7 | bay roberts
# Processing record 34 of set 7 | puerto quijarro
# Processing record 35 of set 7 | enshi
# Processing record 36 of set 7 | rorvik
# Processing record 37 of set 7 | xudat
# Processing record 38 of set 7 | bengkulu
# Processing record 39 of set 7 | marawi
# Processing record 40 of set 7 | rafraf
# Processing record 41 of set 7 | bathsheba
# Processing record 42 of set 7 | paraiso
# Processing record 43 of set 7 | tungkang
# City not found!
# Processing record 44 of set 7 | buchanan
# Processing record 45 of set 7 | ahipara
# Processing record 46 of set 7 | ulaanbaatar
# Processing record 47 of set 7 | boyle
# Processing record 48 of set 7 | scarborough
# Processing record 49 of set 7 | menongue
# Processing record 50 of set 7 | belomorsk
# Processing record 0 of set 8 | taoudenni
# Processing record 1 of set 8 | kamenskoye
# City not found!
# Processing record 2 of set 8 | sur
# Processing record 3 of set 8 | ambilobe
# Processing record 4 of set 8 | aloleng
# Processing record 5 of set 8 | mount isa
# Processing record 6 of set 8 | cockburn town
# Processing record 7 of set 8 | ufimskiy
# Processing record 8 of set 8 | shelburne
# Processing record 9 of set 8 | ozark
# Processing record 10 of set 8 | santa isabel
# Processing record 11 of set 8 | non sang
# Processing record 12 of set 8 | douglas
# Processing record 13 of set 8 | paso de carrasco
# Processing record 14 of set 8 | chambery
# Processing record 15 of set 8 | qaanaaq
# Processing record 16 of set 8 | eskasem
# City not found!
# Processing record 17 of set 8 | narrabri
# Processing record 18 of set 8 | saint-louis
# Processing record 19 of set 8 | kalaleh
# Processing record 20 of set 8 | ajdabiya
# Processing record 21 of set 8 | dhidhdhoo
# Processing record 22 of set 8 | piriyapatna
# Processing record 23 of set 8 | san rafael del sur
# Processing record 24 of set 8 | rumoi
# Processing record 25 of set 8 | garowe
# Processing record 26 of set 8 | pingliang
# Processing record 27 of set 8 | swan river
# Processing record 28 of set 8 | luderitz
# Processing record 29 of set 8 | zlatoustovsk
# City not found!
# Processing record 30 of set 8 | ostrovnoy
# Processing record 31 of set 8 | mercedes
# Processing record 32 of set 8 | novoagansk
# Processing record 33 of set 8 | whitehorse
# Processing record 34 of set 8 | lompoc
# Processing record 35 of set 8 | panjab
# Processing record 36 of set 8 | libourne
# Processing record 37 of set 8 | lodja
# Processing record 38 of set 8 | katherine
# Processing record 39 of set 8 | ayacucho
# Processing record 40 of set 8 | concordia
# Processing record 41 of set 8 | louisbourg
# City not found!
# Processing record 42 of set 8 | anito
# Processing record 43 of set 8 | bluefield
# Processing record 44 of set 8 | harlingen
# Processing record 45 of set 8 | donskoy
# Processing record 46 of set 8 | kasongo-lunda
# Processing record 47 of set 8 | dunedin
# Processing record 48 of set 8 | palabuhanratu
# City not found!
# Processing record 49 of set 8 | la union
# Processing record 50 of set 8 | mackay
# Processing record 0 of set 9 | mullaitivu
# City not found!
# Processing record 1 of set 9 | rawlins
# Processing record 2 of set 9 | japura
# Processing record 3 of set 9 | cerrito
# Processing record 4 of set 9 | kamina
# Processing record 5 of set 9 | zachagansk
# City not found!
# Processing record 6 of set 9 | gambela
# Processing record 7 of set 9 | roald
# Processing record 8 of set 9 | nizwa
# Processing record 9 of set 9 | temaraia
# City not found!
# Processing record 10 of set 9 | moissac
# Processing record 11 of set 9 | san rafael
# Processing record 12 of set 9 | murgab
# Processing record 13 of set 9 | progreso
# Processing record 14 of set 9 | manoel urbano
# Processing record 15 of set 9 | utiroa
# City not found!
# Processing record 16 of set 9 | kapuskasing
# Processing record 17 of set 9 | indramayu
# Processing record 18 of set 9 | caravelas
# Processing record 19 of set 9 | pringsewu
# Processing record 20 of set 9 | karauzyak
# City not found!
# Processing record 21 of set 9 | broken hill
# Processing record 22 of set 9 | maceio
# Processing record 23 of set 9 | centralia
# Processing record 24 of set 9 | sovetskiy
# Processing record 25 of set 9 | padilla
# Processing record 26 of set 9 | naryan-mar
# Processing record 27 of set 9 | karpathos
# Processing record 28 of set 9 | ngukurr
# City not found!
# Processing record 29 of set 9 | taungdwingyi
# Processing record 30 of set 9 | zelenogradsk
# Processing record 31 of set 9 | ruatoria
# City not found!
# Processing record 32 of set 9 | fairbanks
# Processing record 33 of set 9 | porto torres
# Processing record 34 of set 9 | capitan miranda
# Processing record 35 of set 9 | kaka
# Processing record 36 of set 9 | yulara
# Processing record 37 of set 9 | half moon bay
# Processing record 38 of set 9 | metu
# Processing record 39 of set 9 | kargopol
# Processing record 40 of set 9 | sangar
# Processing record 41 of set 9 | mananjary
# Processing record 42 of set 9 | gizo
# Processing record 43 of set 9 | tabiauea
# City not found!
# Processing record 44 of set 9 | ati
# Processing record 45 of set 9 | dauriya
# Processing record 46 of set 9 | novo aripuana
# Processing record 47 of set 9 | batemans bay
# Processing record 48 of set 9 | port augusta
# Processing record 49 of set 9 | manama
# Processing record 50 of set 9 | petropavlovskoye
# Processing record 0 of set 10 | nelson bay
# Processing record 1 of set 10 | tete
# Processing record 2 of set 10 | lodwar
# Processing record 3 of set 10 | darnah
# Processing record 4 of set 10 | soure
# Processing record 5 of set 10 | rome
# Processing record 6 of set 10 | biltine
# Processing record 7 of set 10 | lahad datu
# Processing record 8 of set 10 | puerto lumbreras
# Processing record 9 of set 10 | vavozh
# Processing record 10 of set 10 | kodiak
# Processing record 11 of set 10 | komsomolskiy
# Processing record 12 of set 10 | faya
# Processing record 13 of set 10 | roseburg
# Processing record 14 of set 10 | russell
# Processing record 15 of set 10 | vaitupu
# City not found!
# Processing record 16 of set 10 | pimentel
# Processing record 17 of set 10 | mezen
# Processing record 18 of set 10 | beira
# Processing record 19 of set 10 | dapaong
# Processing record 20 of set 10 | inirida
# Processing record 21 of set 10 | mitu
# Processing record 22 of set 10 | mount darwin
# Processing record 23 of set 10 | tala
# Processing record 24 of set 10 | meadow lake
# Processing record 25 of set 10 | bilibino
# Processing record 26 of set 10 | hamilton
# Processing record 27 of set 10 | hrubieszow
# Processing record 28 of set 10 | tomatlan
# Processing record 29 of set 10 | aguimes
# Processing record 30 of set 10 | abu kamal
# Processing record 31 of set 10 | saint-augustin
# Processing record 32 of set 10 | todos santos
# Processing record 33 of set 10 | helong
# Processing record 34 of set 10 | hovd
# Processing record 35 of set 10 | vetluzhskiy
# Processing record 36 of set 10 | xingyi
# Processing record 37 of set 10 | coro
# Processing record 38 of set 10 | sioux lookout
# Processing record 39 of set 10 | mancio lima
# Processing record 40 of set 10 | kalmunai
# Processing record 41 of set 10 | urucara
# Processing record 42 of set 10 | flinders
# Processing record 43 of set 10 | thinadhoo
# Processing record 44 of set 10 | kununurra
# Processing record 45 of set 10 | wukari
# Processing record 46 of set 10 | nassau
# Processing record 47 of set 10 | cervo
# Processing record 48 of set 10 | cockburn harbour
# City not found!
# Processing record 49 of set 10 | jasidih
# Processing record 50 of set 10 | aksarka
# Processing record 0 of set 11 | nakano
# Processing record 1 of set 11 | bayir
# Processing record 2 of set 11 | yumen
# Processing record 3 of set 11 | newport news
# Processing record 4 of set 11 | novovelichkovskaya
# Processing record 5 of set 11 | tapejara
# Processing record 6 of set 11 | huangpi
# Processing record 7 of set 11 | storforshei
# Processing record 8 of set 11 | deputatskiy
# Processing record 9 of set 11 | pangkalanbuun
# Processing record 10 of set 11 | bam
# Processing record 11 of set 11 | kaya
# Processing record 12 of set 11 | leningradskiy
# Processing record 13 of set 11 | bloomington
# Processing record 14 of set 11 | loiza
# Processing record 15 of set 11 | nenjiang
# Processing record 16 of set 11 | bourail
# Processing record 17 of set 11 | abu dhabi
# Processing record 18 of set 11 | sumbe
# Processing record 19 of set 11 | lubumbashi
# Processing record 20 of set 11 | west wendover
# Processing record 21 of set 11 | duz
# City not found!
# Processing record 22 of set 11 | macau
# Processing record 23 of set 11 | madang
# Processing record 24 of set 11 | grand-lahou
# Processing record 25 of set 11 | yarmouth
# Processing record 26 of set 11 | gari
# Processing record 27 of set 11 | vostok
# Processing record 28 of set 11 | belmonte
# Processing record 29 of set 11 | chimoio
# Processing record 30 of set 11 | vila franca do campo
# Processing record 31 of set 11 | ichinoseki
# Processing record 32 of set 11 | gunjur
# Processing record 33 of set 11 | veraval
# Processing record 34 of set 11 | port hedland
# Processing record 35 of set 11 | nyurba
# Processing record 36 of set 11 | blythe
# Processing record 37 of set 11 | tongchuan
# Processing record 38 of set 11 | culebra
# Processing record 39 of set 11 | zatoka
# Processing record 40 of set 11 | williston
# Processing record 41 of set 11 | yerofey pavlovich
# Processing record 42 of set 11 | kalawit
# Processing record 43 of set 11 | novomyrhorod
# Processing record 44 of set 11 | patancheru
# Processing record 45 of set 11 | eldikan
# City not found!
# Processing record 46 of set 11 | champerico
# Processing record 47 of set 11 | magadan
# Processing record 48 of set 11 | burns lake
# Processing record 49 of set 11 | suntar
# Processing record 50 of set 11 | bandarbeyla
# Processing record 0 of set 12 | synya
# Processing record 1 of set 12 | kutum
# Processing record 2 of set 12 | san vicente
# Processing record 3 of set 12 | malacacheta
# Processing record 4 of set 12 | zhigansk
# Processing record 5 of set 12 | poronaysk
# Processing record 6 of set 12 | nishihara
# Processing record 7 of set 12 | vangaindrano
# Processing record 8 of set 12 | manaus
# Processing record 9 of set 12 | sayyan
# Processing record 10 of set 12 | kedrovyy
# Processing record 11 of set 12 | sarai
# Processing record 12 of set 12 | praia
# Processing record 13 of set 12 | oranjemund
# Processing record 14 of set 12 | kokstad
# Processing record 15 of set 12 | the valley
# Processing record 16 of set 12 | aykhal
# Processing record 17 of set 12 | mago
# Processing record 18 of set 12 | mao
# Processing record 19 of set 12 | borba
# Processing record 20 of set 12 | bosobolo
# Processing record 21 of set 12 | wegorzewo
# Processing record 22 of set 12 | san joaquin
# Processing record 23 of set 12 | tortoli
# Processing record 24 of set 12 | charters towers
# Processing record 25 of set 12 | tarakan
# Processing record 26 of set 12 | mokhsogollokh
# Processing record 27 of set 12 | englewood
# Processing record 28 of set 12 | guozhen
# Processing record 29 of set 12 | langham
# Processing record 30 of set 12 | santa cruz
# -------------------------
# Data Retrieval Complete
# -------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame

# %%
# Create a data frame from cities, temp, humidity, cloudiness and wind speed.
weather_dict = {
    "City": new_cities,
    "Cloudiness" : cloudiness,
    "Country" : country,
    "Date" : date,
    "Humidity" : humidity,
    "Temp": temp,
    "Lat" : lat,
    "Lng" : lng,   
    "Wind Speed" : wind
}
weather_data = pd.DataFrame(weather_dict)
weather_data.count()
# Out:
# City          589
# Cloudiness    589
# Country       589
# Date          589
# Humidity      589
# Temp          589
# Lat           589
# Lng           589
# Wind Speed    589
# dtype: int64

# %%
# Display the dataframe.
weather_data.head()
# Out:
#            City  Cloudiness Country        Date  Humidity  Temp    Lat  \
# 0       ipixuna           4      BR  1601033807        83  80.6  -1.76
# 1     liverpool          40      GB  1601033568        62  57.0  53.41
# 2         vaini          20      TO  1601033779        88  69.8 -21.20
# 3  puerto ayora         100      EC  1601033808        89  68.0  -0.74
# 4        avarua          84      CK  1601033279        88  75.2 -21.21
#
#       Lng  Wind Speed
# 0  -48.80       10.29
# 1   -2.98       25.28
# 2 -175.20        6.93
# 3  -90.35        3.00
# 4 -159.78        5.82

# %%
cities_list = zip(new_cities, cloudiness, country, date, humidity, temp, lat, lng, wind)

# Set variable for output file.
output_file = os.path.join("output_data", "cities.csv")

#  Open the output file.
with open(output_file, 'w') as datafile:
    weather_data.to_csv(output_file)

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
