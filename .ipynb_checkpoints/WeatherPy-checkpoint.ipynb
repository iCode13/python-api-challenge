# %% [markdown]
# # WeatherPy

# %% [markdown]
# #### **Observable Trends**
#
# ##### 1) Temperature shows a strong positive correlation with latitude in both hemispheres.
# ##### 2) Humidity, cloudiness, and wind speed show almost no correlation with latitudes in both hemispheres.
# ##### 3) Even randomly chosen city locations are biased, and are dominantly from the Northern Hemisphere, where majority of the Earth's landmass is concentrated, as we know. The Northern Hemisphere also has more inhabited areas and weather stations at higher latitudes as compared to the Southern Hemisphere.

# %%
# Dependencies and setup.

# %matplotlib inline

import os
import pandas as pd
import numpy as np
import requests
import matplotlib.pyplot as plt
import time
import datetime
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Import citipy to get cities based on latitude and longitude
from citipy import citipy

# Output file (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
# List for holding lat_lngs and cities.
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations.
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat-lng combination.
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # Add to cities list only if city is unique.
    if city not in cities:
         cities.append(city)

# Print the city count to check for sufficient count.
len(cities)
# Out:
# 623

# %%
# Starting empty lists to store all data after retrieval.

new_cities = []
cloudiness = []
country = []
date = []
humidity = []
temp = []
latitude = []
longitude = []
wind = []

# %%
# Starting URL for Open Open Weather Map API Call.

record_counter = 0
set_counter = 0

url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key 

# Print the data header.
print("BEGINNING DATA RETRIEVAL")
print("-----------------------------------------")

for city in cities:
    query_url = url + "&q=" + city
    response = requests.get(query_url).json()
    if record_counter < 50:
        record_counter += 1
    else:
        set_counter += 1
        record_counter = 0

    print('Processing record {} of set {} | {}'.format(record_counter, set_counter, city))
    try:
        cloudiness.append(response['clouds']['all'])
        country.append(response['sys']['country'])
        date.append(response['dt'])          
        humidity.append(response['main']['humidity'])
        temp.append(response['main']['temp_max'])
        latitude.append(response['coord']['lat'])
        longitude.append(response['coord']['lon'])
        wind.append(response['wind']['speed'])
        new_cities.append(city)
    except:
        print("City not found!")
        pass

# Print the data footer to indicate completion of data retrieval.
print("-------------------------")
print("DATA RETRIEVAL COMPLETE")
# Out:
# BEGINNING DATA RETRIEVAL
# -----------------------------------------
# Processing record 1 of set 0 | honiara
# Processing record 2 of set 0 | san vicente de canete
# Processing record 3 of set 0 | klaksvik
# Processing record 4 of set 0 | kysyl-syr
# Processing record 5 of set 0 | haines junction
# Processing record 6 of set 0 | cape town
# Processing record 7 of set 0 | hangu
# Processing record 8 of set 0 | ushuaia
# Processing record 9 of set 0 | ambilobe
# Processing record 10 of set 0 | mudon
# Processing record 11 of set 0 | punta arenas
# Processing record 12 of set 0 | politika
# Processing record 13 of set 0 | necochea
# Processing record 14 of set 0 | sinnamary
# Processing record 15 of set 0 | port alfred
# Processing record 16 of set 0 | rikitea
# Processing record 17 of set 0 | tasiilaq
# Processing record 18 of set 0 | lagoa
# Processing record 19 of set 0 | busselton
# Processing record 20 of set 0 | tuktoyaktuk
# Processing record 21 of set 0 | bejar
# Processing record 22 of set 0 | torbay
# Processing record 23 of set 0 | yenagoa
# Processing record 24 of set 0 | asau
# Processing record 25 of set 0 | satitoa
# City not found!
# Processing record 26 of set 0 | geraldton
# Processing record 27 of set 0 | osakarovka
# Processing record 28 of set 0 | tessalit
# Processing record 29 of set 0 | cayenne
# Processing record 30 of set 0 | butaritari
# Processing record 31 of set 0 | avarua
# Processing record 32 of set 0 | port moresby
# Processing record 33 of set 0 | hamilton
# Processing record 34 of set 0 | hermanus
# Processing record 35 of set 0 | amambai
# Processing record 36 of set 0 | cabo san lucas
# Processing record 37 of set 0 | longyearbyen
# Processing record 38 of set 0 | bethel
# Processing record 39 of set 0 | bambous virieux
# Processing record 40 of set 0 | fukue
# Processing record 41 of set 0 | mocambique
# City not found!
# Processing record 42 of set 0 | saint george
# Processing record 43 of set 0 | merauke
# Processing record 44 of set 0 | atuona
# Processing record 45 of set 0 | tumannyy
# City not found!
# Processing record 46 of set 0 | vaini
# Processing record 47 of set 0 | vila franca do campo
# Processing record 48 of set 0 | chuy
# Processing record 49 of set 0 | nikolskoye
# Processing record 50 of set 0 | belushya guba
# City not found!
# Processing record 0 of set 1 | bluff
# Processing record 1 of set 1 | vytegra
# Processing record 2 of set 1 | tahe
# Processing record 3 of set 1 | chokurdakh
# Processing record 4 of set 1 | college
# Processing record 5 of set 1 | iqaluit
# Processing record 6 of set 1 | invermere
# Processing record 7 of set 1 | mys shmidta
# City not found!
# Processing record 8 of set 1 | nanortalik
# Processing record 9 of set 1 | taolanaro
# City not found!
# Processing record 10 of set 1 | ingham
# Processing record 11 of set 1 | kruisfontein
# Processing record 12 of set 1 | beidao
# Processing record 13 of set 1 | narsaq
# Processing record 14 of set 1 | illoqqortoormiut
# City not found!
# Processing record 15 of set 1 | castro
# Processing record 16 of set 1 | hambantota
# Processing record 17 of set 1 | puerto ayora
# Processing record 18 of set 1 | baglan
# Processing record 19 of set 1 | tura
# Processing record 20 of set 1 | port elizabeth
# Processing record 21 of set 1 | mataura
# Processing record 22 of set 1 | severo-kurilsk
# Processing record 23 of set 1 | jamestown
# Processing record 24 of set 1 | temaraia
# City not found!
# Processing record 25 of set 1 | kaitangata
# Processing record 26 of set 1 | new norfolk
# Processing record 27 of set 1 | oussouye
# Processing record 28 of set 1 | skalistyy
# City not found!
# Processing record 29 of set 1 | ponta do sol
# Processing record 30 of set 1 | eureka
# Processing record 31 of set 1 | bengkulu
# Processing record 32 of set 1 | hilo
# Processing record 33 of set 1 | talnakh
# Processing record 34 of set 1 | hobart
# Processing record 35 of set 1 | broome
# Processing record 36 of set 1 | anchorage
# Processing record 37 of set 1 | albany
# Processing record 38 of set 1 | rawlins
# Processing record 39 of set 1 | figeac
# Processing record 40 of set 1 | fenoarivo
# Processing record 41 of set 1 | gabu
# Processing record 42 of set 1 | airai
# Processing record 43 of set 1 | beckley
# Processing record 44 of set 1 | novoorsk
# Processing record 45 of set 1 | aswan
# Processing record 46 of set 1 | sayyan
# Processing record 47 of set 1 | yar-sale
# Processing record 48 of set 1 | neuquen
# Processing record 49 of set 1 | lazaro cardenas
# Processing record 50 of set 1 | awjilah
# Processing record 0 of set 2 | pevek
# Processing record 1 of set 2 | coquimbo
# Processing record 2 of set 2 | khatanga
# Processing record 3 of set 2 | manzil salim
# Processing record 4 of set 2 | clyde river
# Processing record 5 of set 2 | kerema
# Processing record 6 of set 2 | mafinga
# Processing record 7 of set 2 | acarau
# Processing record 8 of set 2 | fortuna
# Processing record 9 of set 2 | thompson
# Processing record 10 of set 2 | holalkere
# Processing record 11 of set 2 | georgetown
# Processing record 12 of set 2 | katsuura
# Processing record 13 of set 2 | nicoya
# Processing record 14 of set 2 | hutang
# Processing record 15 of set 2 | hofn
# Processing record 16 of set 2 | bagdarin
# Processing record 17 of set 2 | kapaa
# Processing record 18 of set 2 | fort nelson
# Processing record 19 of set 2 | grand gaube
# Processing record 20 of set 2 | methven
# Processing record 21 of set 2 | opuwo
# Processing record 22 of set 2 | tres arroyos
# Processing record 23 of set 2 | agadez
# Processing record 24 of set 2 | kapoeta
# Processing record 25 of set 2 | faanui
# Processing record 26 of set 2 | homer
# Processing record 27 of set 2 | pangnirtung
# Processing record 28 of set 2 | sept-iles
# Processing record 29 of set 2 | bredasdorp
# Processing record 30 of set 2 | deputatskiy
# Processing record 31 of set 2 | muros
# Processing record 32 of set 2 | barrow
# Processing record 33 of set 2 | skiros
# City not found!
# Processing record 34 of set 2 | saint-philippe
# Processing record 35 of set 2 | tianpeng
# Processing record 36 of set 2 | skagastrond
# City not found!
# Processing record 37 of set 2 | esperance
# Processing record 38 of set 2 | bowen
# Processing record 39 of set 2 | perelyub
# Processing record 40 of set 2 | hithadhoo
# Processing record 41 of set 2 | bonavista
# Processing record 42 of set 2 | tiksi
# Processing record 43 of set 2 | makakilo city
# Processing record 44 of set 2 | upernavik
# Processing record 45 of set 2 | praya
# Processing record 46 of set 2 | barbacoas
# Processing record 47 of set 2 | pierre
# Processing record 48 of set 2 | omboue
# Processing record 49 of set 2 | te anau
# Processing record 50 of set 2 | boende
# Processing record 0 of set 3 | marsa matruh
# Processing record 1 of set 3 | shimoda
# Processing record 2 of set 3 | palkaka
# City not found!
# Processing record 3 of set 3 | kodiak
# Processing record 4 of set 3 | kavaratti
# Processing record 5 of set 3 | yellowknife
# Processing record 6 of set 3 | adrar
# Processing record 7 of set 3 | zhuhai
# Processing record 8 of set 3 | dunmore east
# Processing record 9 of set 3 | mar del plata
# Processing record 10 of set 3 | brownsville
# Processing record 11 of set 3 | laela
# Processing record 12 of set 3 | riyadh
# Processing record 13 of set 3 | gat
# Processing record 14 of set 3 | barentsburg
# City not found!
# Processing record 15 of set 3 | kavieng
# Processing record 16 of set 3 | namatanai
# Processing record 17 of set 3 | parabel
# Processing record 18 of set 3 | saint anthony
# Processing record 19 of set 3 | morondava
# Processing record 20 of set 3 | north platte
# Processing record 21 of set 3 | mtwara
# Processing record 22 of set 3 | celestun
# Processing record 23 of set 3 | bustamante
# Processing record 24 of set 3 | ribeira grande
# Processing record 25 of set 3 | surt
# Processing record 26 of set 3 | iraucuba
# Processing record 27 of set 3 | high level
# Processing record 28 of set 3 | andenes
# Processing record 29 of set 3 | azambuja
# Processing record 30 of set 3 | west point
# Processing record 31 of set 3 | norman wells
# Processing record 32 of set 3 | dandong
# Processing record 33 of set 3 | garissa
# Processing record 34 of set 3 | sawtell
# Processing record 35 of set 3 | ancud
# Processing record 36 of set 3 | moindou
# Processing record 37 of set 3 | terekli-mekteb
# Processing record 38 of set 3 | frederico westphalen
# Processing record 39 of set 3 | dickinson
# Processing record 40 of set 3 | bonthe
# Processing record 41 of set 3 | mayahi
# Processing record 42 of set 3 | hasaki
# Processing record 43 of set 3 | assomada
# Processing record 44 of set 3 | port lincoln
# Processing record 45 of set 3 | iracoubo
# Processing record 46 of set 3 | qaanaaq
# Processing record 47 of set 3 | zeya
# Processing record 48 of set 3 | garden city
# Processing record 49 of set 3 | soyo
# Processing record 50 of set 3 | piacabucu
# Processing record 0 of set 4 | nouadhibou
# Processing record 1 of set 4 | anadyr
# Processing record 2 of set 4 | san policarpo
# Processing record 3 of set 4 | carballo
# Processing record 4 of set 4 | uusikaupunki
# Processing record 5 of set 4 | wanderlandia
# City not found!
# Processing record 6 of set 4 | verkhoyansk
# Processing record 7 of set 4 | xining
# Processing record 8 of set 4 | cherskiy
# Processing record 9 of set 4 | sentyabrskiy
# City not found!
# Processing record 10 of set 4 | mahebourg
# Processing record 11 of set 4 | maniitsoq
# Processing record 12 of set 4 | grindavik
# Processing record 13 of set 4 | attawapiskat
# City not found!
# Processing record 14 of set 4 | igarka
# Processing record 15 of set 4 | kawana waters
# City not found!
# Processing record 16 of set 4 | margate
# Processing record 17 of set 4 | guerrero negro
# Processing record 18 of set 4 | tibati
# Processing record 19 of set 4 | dauphin
# Processing record 20 of set 4 | serenje
# Processing record 21 of set 4 | tabulbah
# City not found!
# Processing record 22 of set 4 | mwinilunga
# Processing record 23 of set 4 | kemang
# Processing record 24 of set 4 | barbar
# City not found!
# Processing record 25 of set 4 | port macquarie
# Processing record 26 of set 4 | provideniya
# Processing record 27 of set 4 | sao joao da barra
# Processing record 28 of set 4 | floro
# Processing record 29 of set 4 | rocha
# Processing record 30 of set 4 | lavrentiya
# Processing record 31 of set 4 | waipawa
# Processing record 32 of set 4 | byron bay
# Processing record 33 of set 4 | pa daet
# Processing record 34 of set 4 | serdobsk
# Processing record 35 of set 4 | shingu
# Processing record 36 of set 4 | rovaniemi
# Processing record 37 of set 4 | luderitz
# Processing record 38 of set 4 | ha giang
# Processing record 39 of set 4 | phan thiet
# Processing record 40 of set 4 | saldanha
# Processing record 41 of set 4 | alofi
# Processing record 42 of set 4 | tel aviv-yafo
# Processing record 43 of set 4 | gorele
# Processing record 44 of set 4 | mayumba
# Processing record 45 of set 4 | tazovskiy
# Processing record 46 of set 4 | ponta delgada
# Processing record 47 of set 4 | quixada
# Processing record 48 of set 4 | tsiroanomandidy
# Processing record 49 of set 4 | opobo
# City not found!
# Processing record 50 of set 4 | tuatapere
# Processing record 0 of set 5 | santo tomas
# Processing record 1 of set 5 | isangel
# Processing record 2 of set 5 | miyazu
# Processing record 3 of set 5 | east london
# Processing record 4 of set 5 | sitka
# Processing record 5 of set 5 | nemuro
# Processing record 6 of set 5 | piojo
# Processing record 7 of set 5 | dikson
# Processing record 8 of set 5 | muzhi
# Processing record 9 of set 5 | teguise
# Processing record 10 of set 5 | araouane
# Processing record 11 of set 5 | nishihara
# Processing record 12 of set 5 | solnechnyy
# Processing record 13 of set 5 | sakakah
# Processing record 14 of set 5 | nalut
# Processing record 15 of set 5 | terrace
# Processing record 16 of set 5 | bathsheba
# Processing record 17 of set 5 | huarmey
# Processing record 18 of set 5 | ennepetal
# Processing record 19 of set 5 | antofagasta
# Processing record 20 of set 5 | zapolyarnyy
# Processing record 21 of set 5 | rafaela
# Processing record 22 of set 5 | hay river
# Processing record 23 of set 5 | dingle
# Processing record 24 of set 5 | panama city
# Processing record 25 of set 5 | kataysk
# Processing record 26 of set 5 | shibata
# Processing record 27 of set 5 | yuzhno-yeniseyskiy
# City not found!
# Processing record 28 of set 5 | victoria point
# Processing record 29 of set 5 | oranzherei
# Processing record 30 of set 5 | kirakira
# Processing record 31 of set 5 | warrnambool
# Processing record 32 of set 5 | tual
# Processing record 33 of set 5 | artesia
# Processing record 34 of set 5 | abu jubayhah
# City not found!
# Processing record 35 of set 5 | mpika
# Processing record 36 of set 5 | barinas
# Processing record 37 of set 5 | dali
# Processing record 38 of set 5 | saskylakh
# Processing record 39 of set 5 | carnarvon
# Processing record 40 of set 5 | san patricio
# Processing record 41 of set 5 | marshfield
# Processing record 42 of set 5 | pokhara
# Processing record 43 of set 5 | iralaya
# Processing record 44 of set 5 | puerto del rosario
# Processing record 45 of set 5 | palembang
# Processing record 46 of set 5 | vaitupu
# City not found!
# Processing record 47 of set 5 | victoria
# Processing record 48 of set 5 | cockburn town
# Processing record 49 of set 5 | mersing
# Processing record 50 of set 5 | palabuhanratu
# City not found!
# Processing record 0 of set 6 | takanabe
# Processing record 1 of set 6 | bangassou
# Processing record 2 of set 6 | lorengau
# Processing record 3 of set 6 | pondicherry
# Processing record 4 of set 6 | djambala
# Processing record 5 of set 6 | mahajanga
# Processing record 6 of set 6 | marovoay
# Processing record 7 of set 6 | phalombe
# Processing record 8 of set 6 | khandyga
# Processing record 9 of set 6 | yangambi
# Processing record 10 of set 6 | chiredzi
# Processing record 11 of set 6 | mount isa
# Processing record 12 of set 6 | kuching
# Processing record 13 of set 6 | dibulla
# Processing record 14 of set 6 | aklavik
# Processing record 15 of set 6 | barra do garcas
# Processing record 16 of set 6 | ilulissat
# Processing record 17 of set 6 | nizhneyansk
# City not found!
# Processing record 18 of set 6 | meru
# Processing record 19 of set 6 | noyabrsk
# Processing record 20 of set 6 | frasinet
# Processing record 21 of set 6 | saint-louis
# Processing record 22 of set 6 | biak
# Processing record 23 of set 6 | sungairaya
# Processing record 24 of set 6 | suntar
# Processing record 25 of set 6 | tombouctou
# Processing record 26 of set 6 | brookhaven
# Processing record 27 of set 6 | tucuman
# Processing record 28 of set 6 | kahului
# Processing record 29 of set 6 | mirpur sakro
# Processing record 30 of set 6 | tsihombe
# City not found!
# Processing record 31 of set 6 | tautira
# Processing record 32 of set 6 | cidreira
# Processing record 33 of set 6 | neryungri
# Processing record 34 of set 6 | chokwe
# Processing record 35 of set 6 | oytal
# Processing record 36 of set 6 | sistranda
# Processing record 37 of set 6 | torrox
# Processing record 38 of set 6 | egvekinot
# Processing record 39 of set 6 | angoche
# Processing record 40 of set 6 | tabiauea
# City not found!
# Processing record 41 of set 6 | tawala
# Processing record 42 of set 6 | kankaanpaa
# Processing record 43 of set 6 | faya
# Processing record 44 of set 6 | saint combs
# City not found!
# Processing record 45 of set 6 | edd
# Processing record 46 of set 6 | dukat
# Processing record 47 of set 6 | tommot
# Processing record 48 of set 6 | ossora
# Processing record 49 of set 6 | eskasem
# City not found!
# Processing record 50 of set 6 | thyolo
# Processing record 0 of set 7 | puerto plata
# Processing record 1 of set 7 | ginir
# Processing record 2 of set 7 | dingzhou
# Processing record 3 of set 7 | hailar
# Processing record 4 of set 7 | bima
# Processing record 5 of set 7 | abidjan
# Processing record 6 of set 7 | kayerkan
# Processing record 7 of set 7 | abu dhabi
# Processing record 8 of set 7 | kurumkan
# Processing record 9 of set 7 | salalah
# Processing record 10 of set 7 | goderich
# Processing record 11 of set 7 | camacha
# Processing record 12 of set 7 | lompoc
# Processing record 13 of set 7 | maine-soroa
# Processing record 14 of set 7 | pisco
# Processing record 15 of set 7 | sindand
# City not found!
# Processing record 16 of set 7 | senhor do bonfim
# Processing record 17 of set 7 | naters
# Processing record 18 of set 7 | ahipara
# Processing record 19 of set 7 | korla
# Processing record 20 of set 7 | sao felix do xingu
# Processing record 21 of set 7 | jasper
# Processing record 22 of set 7 | palasa
# Processing record 23 of set 7 | rawson
# Processing record 24 of set 7 | tasgaon
# Processing record 25 of set 7 | nueva loja
# Processing record 26 of set 7 | ciudad bolivar
# Processing record 27 of set 7 | magadan
# Processing record 28 of set 7 | samagaltay
# Processing record 29 of set 7 | one hundred mile house
# City not found!
# Processing record 30 of set 7 | khorramshahr
# Processing record 31 of set 7 | souillac
# Processing record 32 of set 7 | contamana
# Processing record 33 of set 7 | petropavlovsk-kamchatskiy
# Processing record 34 of set 7 | emerald
# Processing record 35 of set 7 | hangzhou
# Processing record 36 of set 7 | sorong
# Processing record 37 of set 7 | quatre cocos
# Processing record 38 of set 7 | westport
# Processing record 39 of set 7 | negele
# City not found!
# Processing record 40 of set 7 | lebu
# Processing record 41 of set 7 | zhoucheng
# Processing record 42 of set 7 | kismayo
# Processing record 43 of set 7 | vereeniging
# Processing record 44 of set 7 | jalgaon
# Processing record 45 of set 7 | atar
# Processing record 46 of set 7 | gwadar
# Processing record 47 of set 7 | san lawrenz
# Processing record 48 of set 7 | peski
# Processing record 49 of set 7 | alice springs
# Processing record 50 of set 7 | amuntai
# Processing record 0 of set 8 | new ulm
# Processing record 1 of set 8 | cherepovets
# Processing record 2 of set 8 | verkhnevilyuysk
# Processing record 3 of set 8 | meulaboh
# Processing record 4 of set 8 | mizusawa
# Processing record 5 of set 8 | yuanping
# Processing record 6 of set 8 | kupang
# Processing record 7 of set 8 | paradwip
# City not found!
# Processing record 8 of set 8 | pirenopolis
# Processing record 9 of set 8 | birjand
# Processing record 10 of set 8 | vitim
# Processing record 11 of set 8 | leningradskiy
# Processing record 12 of set 8 | pitimbu
# Processing record 13 of set 8 | teya
# Processing record 14 of set 8 | hohhot
# Processing record 15 of set 8 | samarai
# Processing record 16 of set 8 | dennery
# Processing record 17 of set 8 | tara
# Processing record 18 of set 8 | kungurtug
# Processing record 19 of set 8 | vicuna
# Processing record 20 of set 8 | vidalia
# Processing record 21 of set 8 | richards bay
# Processing record 22 of set 8 | dunedin
# Processing record 23 of set 8 | baiyin
# Processing record 24 of set 8 | samusu
# City not found!
# Processing record 25 of set 8 | kingsville
# Processing record 26 of set 8 | haibowan
# City not found!
# Processing record 27 of set 8 | champagnole
# Processing record 28 of set 8 | bemidji
# Processing record 29 of set 8 | amberley
# Processing record 30 of set 8 | san isidro
# Processing record 31 of set 8 | nome
# Processing record 32 of set 8 | cabedelo
# Processing record 33 of set 8 | fairbanks
# Processing record 34 of set 8 | christchurch
# Processing record 35 of set 8 | taksimo
# Processing record 36 of set 8 | sampues
# Processing record 37 of set 8 | bandarbeyla
# Processing record 38 of set 8 | najran
# Processing record 39 of set 8 | zhigansk
# Processing record 40 of set 8 | mabaruma
# Processing record 41 of set 8 | palu
# Processing record 42 of set 8 | buin
# Processing record 43 of set 8 | bridlington
# Processing record 44 of set 8 | magan
# Processing record 45 of set 8 | tsienyane
# City not found!
# Processing record 46 of set 8 | lagos
# Processing record 47 of set 8 | ambovombe
# Processing record 48 of set 8 | balabac
# Processing record 49 of set 8 | buraydah
# Processing record 50 of set 8 | mangrol
# Processing record 0 of set 9 | baturaja
# Processing record 1 of set 9 | mandal
# Processing record 2 of set 9 | talaya
# Processing record 3 of set 9 | tecoanapa
# Processing record 4 of set 9 | chapais
# Processing record 5 of set 9 | gushikawa
# Processing record 6 of set 9 | lensk
# Processing record 7 of set 9 | bolungarvik
# City not found!
# Processing record 8 of set 9 | ostrovnoy
# Processing record 9 of set 9 | bilibino
# Processing record 10 of set 9 | miranda
# Processing record 11 of set 9 | andarab
# City not found!
# Processing record 12 of set 9 | eskil
# Processing record 13 of set 9 | katangli
# Processing record 14 of set 9 | bria
# Processing record 15 of set 9 | lhokseumawe
# Processing record 16 of set 9 | rongcheng
# Processing record 17 of set 9 | matadi
# Processing record 18 of set 9 | pahrump
# Processing record 19 of set 9 | young
# Processing record 20 of set 9 | grand centre
# City not found!
# Processing record 21 of set 9 | ocean city
# Processing record 22 of set 9 | taburi
# City not found!
# Processing record 23 of set 9 | umzimvubu
# City not found!
# Processing record 24 of set 9 | tabuk
# Processing record 25 of set 9 | yerbogachen
# Processing record 26 of set 9 | rosario do sul
# Processing record 27 of set 9 | nelson bay
# Processing record 28 of set 9 | kulhudhuffushi
# Processing record 29 of set 9 | san vicente
# Processing record 30 of set 9 | berlevag
# Processing record 31 of set 9 | la brea
# Processing record 32 of set 9 | ulladulla
# Processing record 33 of set 9 | vanavara
# Processing record 34 of set 9 | humberto de campos
# Processing record 35 of set 9 | iseyin
# Processing record 36 of set 9 | auki
# Processing record 37 of set 9 | shitanjing
# Processing record 38 of set 9 | spanish lake
# Processing record 39 of set 9 | kedarnath
# City not found!
# Processing record 40 of set 9 | chimbarongo
# Processing record 41 of set 9 | vestmannaeyjar
# Processing record 42 of set 9 | touros
# Processing record 43 of set 9 | ilebo
# Processing record 44 of set 9 | saint-augustin
# Processing record 45 of set 9 | tadine
# Processing record 46 of set 9 | nosy varika
# Processing record 47 of set 9 | codrington
# Processing record 48 of set 9 | port said
# Processing record 49 of set 9 | maumere
# Processing record 50 of set 9 | ketchikan
# Processing record 0 of set 10 | kutum
# Processing record 1 of set 10 | vao
# Processing record 2 of set 10 | husavik
# Processing record 3 of set 10 | karachi
# Processing record 4 of set 10 | vagur
# Processing record 5 of set 10 | amderma
# City not found!
# Processing record 6 of set 10 | maposeni
# Processing record 7 of set 10 | tevaitoa
# Processing record 8 of set 10 | comodoro rivadavia
# Processing record 9 of set 10 | troitskoye
# Processing record 10 of set 10 | banda aceh
# Processing record 11 of set 10 | lasa
# Processing record 12 of set 10 | kununurra
# Processing record 13 of set 10 | longyan
# Processing record 14 of set 10 | sitio novo do tocantins
# Processing record 15 of set 10 | glogow
# Processing record 16 of set 10 | mahadday weyne
# City not found!
# Processing record 17 of set 10 | brewster
# Processing record 18 of set 10 | manggar
# Processing record 19 of set 10 | taoudenni
# Processing record 20 of set 10 | nueva concepcion
# Processing record 21 of set 10 | polovinnoye
# Processing record 22 of set 10 | fayetteville
# Processing record 23 of set 10 | wexford
# Processing record 24 of set 10 | coruripe
# Processing record 25 of set 10 | kidal
# Processing record 26 of set 10 | palana
# Processing record 27 of set 10 | zaysan
# Processing record 28 of set 10 | gornopravdinsk
# Processing record 29 of set 10 | half moon bay
# Processing record 30 of set 10 | kiama
# Processing record 31 of set 10 | mount gambier
# Processing record 32 of set 10 | nuuk
# Processing record 33 of set 10 | ji-parana
# City not found!
# Processing record 34 of set 10 | mardin
# Processing record 35 of set 10 | acapulco
# Processing record 36 of set 10 | conceicao do araguaia
# Processing record 37 of set 10 | ust-kamchatsk
# City not found!
# Processing record 38 of set 10 | lumberton
# Processing record 39 of set 10 | marcona
# City not found!
# Processing record 40 of set 10 | arlit
# Processing record 41 of set 10 | woodstock
# Processing record 42 of set 10 | mitu
# Processing record 43 of set 10 | chapleau
# Processing record 44 of set 10 | nong phai
# Processing record 45 of set 10 | dhidhdhoo
# Processing record 46 of set 10 | tiznit
# Processing record 47 of set 10 | yumen
# Processing record 48 of set 10 | hami
# Processing record 49 of set 10 | blenheim
# Processing record 50 of set 10 | monrovia
# Processing record 0 of set 11 | lardos
# Processing record 1 of set 11 | port blair
# Processing record 2 of set 11 | malwan
# City not found!
# Processing record 3 of set 11 | arraial do cabo
# Processing record 4 of set 11 | maceio
# Processing record 5 of set 11 | vrangel
# Processing record 6 of set 11 | romans-sur-isere
# Processing record 7 of set 11 | oktyabrskiy
# Processing record 8 of set 11 | inuvik
# Processing record 9 of set 11 | abrau-dyurso
# Processing record 10 of set 11 | caraballeda
# Processing record 11 of set 11 | namibe
# Processing record 12 of set 11 | manokwari
# Processing record 13 of set 11 | oarai
# Processing record 14 of set 11 | meyungs
# City not found!
# Processing record 15 of set 11 | honningsvag
# Processing record 16 of set 11 | lithakia
# Processing record 17 of set 11 | burnie
# Processing record 18 of set 11 | mergui
# City not found!
# Processing record 19 of set 11 | mouzakion
# City not found!
# Processing record 20 of set 11 | el alto
# Processing record 21 of set 11 | flin flon
# Processing record 22 of set 11 | belaya gora
# Processing record 23 of set 11 | kaminoyama
# Processing record 24 of set 11 | heihe
# Processing record 25 of set 11 | sumbawa
# City not found!
# Processing record 26 of set 11 | conceicao da feira
# Processing record 27 of set 11 | xunchang
# Processing record 28 of set 11 | mecca
# Processing record 29 of set 11 | lumphat
# Processing record 30 of set 11 | kpandae
# Processing record 31 of set 11 | chai nat
# Processing record 32 of set 11 | abha
# Processing record 33 of set 11 | midland
# Processing record 34 of set 11 | det udom
# Processing record 35 of set 11 | tukrah
# Processing record 36 of set 11 | biskupiec
# Processing record 37 of set 11 | sabang
# Processing record 38 of set 11 | batagay
# Processing record 39 of set 11 | mehamn
# Processing record 40 of set 11 | kisangani
# Processing record 41 of set 11 | shimanovsk
# Processing record 42 of set 11 | gobabis
# Processing record 43 of set 11 | finschhafen
# Processing record 44 of set 11 | the valley
# Processing record 45 of set 11 | nizhniy tsasuchey
# Processing record 46 of set 11 | shelburne
# Processing record 47 of set 11 | vila velha
# Processing record 48 of set 11 | khaniotis
# Processing record 49 of set 11 | prachuap khiri khan
# Processing record 50 of set 11 | los llanos de aridane
# Processing record 0 of set 12 | newport
# Processing record 1 of set 12 | gorom-gorom
# Processing record 2 of set 12 | saint-pierre
# Processing record 3 of set 12 | jumla
# Processing record 4 of set 12 | nantucket
# Processing record 5 of set 12 | veraval
# Processing record 6 of set 12 | nago
# Processing record 7 of set 12 | delta
# Processing record 8 of set 12 | kegayli
# City not found!
# Processing record 9 of set 12 | maldonado
# Processing record 10 of set 12 | hammerfest
# Processing record 11 of set 12 | west wendover
# -------------------------
# DATA RETRIEVAL COMPLETE

# %%
# Create a dataframe from array of JSONs.
weather_dict = {
    "City": new_cities,
    "Latitude" : latitude,
    "Longitude" : longitude, 
    "Country" : country,
    "Wind Speed" : wind,   
    "Max Temp": temp,
    "Humidity" : humidity,
    "Cloudiness" : cloudiness,
    "Date" : date
}
weather_data = pd.DataFrame(weather_dict)
weather_data.count()
# Out:
# City          570
# Latitude      570
# Longitude     570
# Country       570
# Wind Speed    570
# Max Temp      570
# Humidity      570
# Cloudiness    570
# Date          570
# dtype: int64

# %%
# Display the dataframe.        
weather_data.head()
# Out:
#                     City  Latitude  Longitude Country  Wind Speed  Max Temp  \
# 0                honiara     -9.43     159.95      SB       12.75     87.80
# 1  san vicente de canete    -13.08     -76.38      PE        3.87     61.05
# 2               klaksvik     62.23      -6.59      FO       11.41     44.60
# 3              kysyl-syr     63.90     122.76      RU        6.33     47.34
# 4        haines junction     60.75    -137.51      CA        7.20     49.55
#
#    Humidity  Cloudiness        Date
# 0        62          40  1601166207
# 1        80          12  1601166207
# 2        87         100  1601166207
# 3        91         100  1601166207
# 4        65          88  1601166182

# %%
cities_list = zip(new_cities, latitude, longitude, country, temp, humidity, cloudiness, wind, date)

# Set variable for output file.
output_file = os.path.join("output_data", "cities.csv")

#  Open the output file.
with open(output_file, 'w') as datafile:
    weather_data.to_csv(output_file)

# %%
#  Get indices of cities with humidity over 100%.
all_weather_data = weather_data[(weather_data["Humidity"] > 100)].index

# Make new dataframe after dropping all humidity > 100% by index.
weather_data_final = weather_data.drop(all_weather_data, inplace=False)
weather_data_final
# Out:
#                       City  Latitude  Longitude Country  Wind Speed  Max Temp  \
# 0                  honiara     -9.43     159.95      SB       12.75     87.80
# 1    san vicente de canete    -13.08     -76.38      PE        3.87     61.05
# 2                 klaksvik     62.23      -6.59      FO       11.41     44.60
# 3                kysyl-syr     63.90     122.76      RU        6.33     47.34
# 4          haines junction     60.75    -137.51      CA        7.20     49.55
# ..                     ...       ...        ...     ...         ...       ...
# 565                   nago     26.59     127.98      JP        3.36     71.60
# 566                  delta      5.50       6.00      NG        1.81     73.17
# 567              maldonado    -34.67     -54.92      UY        4.70     62.60
# 568             hammerfest     70.66      23.68      NO       21.92     41.00
# 569          west wendover     40.74    -114.07      US       13.87     71.60
#
#      Humidity  Cloudiness        Date
# 0          62          40  1601166207
# 1          80          12  1601166207
# 2          87         100  1601166207
# 3          91         100  1601166207
# 4          65          88  1601166182
# ..        ...         ...         ...
# 565        88          90  1601166337
# 566        96         100  1601166337
# 567        88          75  1601166110
# 568        65          13  1601166337
# 569        35           1  1601166338
#
# [570 rows x 9 columns]

# %%
# Extract fields from dataframe.
lats = weather_data_final["Latitude"]
max_temps = weather_data_final["Max Temp"]
humidity = weather_data_final["Humidity"]
cloudiness = weather_data_final["Cloudiness"]
wind_speed = weather_data_final["Wind Speed"]

# Export data to a csv file.
weather_data_final.to_csv(output_data_file, index_label="City_ID")

# %% [markdown]
# ## **Plotting the Data**

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
# Format date stamp

date = datetime.datetime.fromtimestamp(
        int(weather_data['Date'][0])
    ).strftime('%m/%d/%Y')

print(date)
# Out:
# 09/27/2020

# %%
weather_data_final.plot(kind="scatter", x="Latitude", y="Max Temp", c="DarkOrange")
plt.title("Temperature vs. City Latitude ({})".format(date))
plt.xlabel("Latitude (degrees)")
plt.xlim([-90, 90])
plt.ylabel("Temperature (F)")
plt.grid()
plt.savefig("output_data/Temperature_vs_Latitude.png")

# %% [markdown]
# ##### Matplotlib is used to prepare the above plot. The code defines the plot type and plot area, and adds title and axes labels. Finally, it is saved as a PNG file.
# #####  Analysis: The plot demonstrates that temperatures are higher at lower latitudes, as we get closer to the Equator. It also shows an overall higher number of cities were randomly chosen from the Northern Hemisphere.

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
weather_data_final.plot(kind="scatter",x="Latitude",y="Humidity", c="Blue")
plt.title("Humidity vs. City Latitude ({})".format(date))
plt.xlabel("Latitude (degrees)")
plt.xlim([-90, 90])
plt.ylabel("Humidity (%)")
plt.grid()
plt.savefig("output_data/Humidity_vs_Latitude.png")

# %% [markdown]
# ##### Matplotlib is used to prepare the above plot. The code defines the plot type and plot area, and adds title and axes labels. Finally, it is saved as a PNG file.
# ##### Analysis: The plot demonstrates that high humidites are found at all latitudes, but lower and medium humidity levels seem to be concentrated within the 10-40 degree latitude range to both the north and south of the Equator. It also shows an overall higher number of cities were randomly chosen from the Northern Hemisphere.

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
weather_data_final.plot(kind="scatter",x="Latitude",y="Cloudiness", c="Cyan")
plt.title("Cloudiness vs. City Latitude ({})".format(date))
plt.xlabel("Latitude (degrees)")
plt.xlim([-90, 90])
plt.ylabel("Cloudiness (%)")
plt.grid()
plt.savefig("output_data/Cloudiness_vs_Latitude.png")

# %% [markdown]
# ##### Matplotlib is used to prepare the above plot. The code defines the plot type and plot area, and adds title and axes labels. Finally, it is saved as a PNG file.
# ##### Analysis: The plot shows no specific relationship between cloudiness and latitude since all levels of cloudiness occur at all latitudes. It also shows an overall higher number of cities were randomly chosen from the Northern Hemisphere.

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
weather_data_final.plot(kind="scatter",x="Latitude",y="Wind Speed", c="Green")
plt.title("Wind Speed vs. City Latitude ({})".format(date))
plt.xlabel("Latitude (degrees)")
plt.xlim([-90, 90])
plt.ylabel("Wind Speed (mph)")
plt.grid()
plt.savefig("output_data/WindSpeed_vs_Latitude.png")

# %% [markdown]
# ##### Matplotlib is used to prepare the above plot. The code defines the plot type and plot area, and adds title and axes labels. Finally, it is saved as a PNG file.
# ##### Analysis: The plot shows no specific relation between wind and latitude since all wind speeds occur at all latitudes. It also shows an overall higher number of cities were randomly chosen from the Northern Hemisphere.

# %% [markdown]
# ## **Linear Regression**

# %%
# Create Northern and Southern Hemisphere dataframes.

N_hemi_df = weather_data_final.loc[weather_data_final["Latitude"]>0]
S_hemi_df = weather_data_final.loc[weather_data_final["Latitude"]<0]

# %%
N_hemi_df
# Out:
#                 City  Latitude  Longitude Country  Wind Speed  Max Temp  \
# 2           klaksvik     62.23      -6.59      FO       11.41     44.60
# 3          kysyl-syr     63.90     122.76      RU        6.33     47.34
# 4    haines junction     60.75    -137.51      CA        7.20     49.55
# 6              hangu     39.25     117.79      CN        2.24     68.00
# 9              mudon     16.26      97.72      MM        2.42     77.22
# ..               ...       ...        ...     ...         ...       ...
# 564          veraval     20.90      70.37      IN        8.84     79.16
# 565             nago     26.59     127.98      JP        3.36     71.60
# 566            delta      5.50       6.00      NG        1.81     73.17
# 568       hammerfest     70.66      23.68      NO       21.92     41.00
# 569    west wendover     40.74    -114.07      US       13.87     71.60
#
#      Humidity  Cloudiness        Date
# 2          87         100  1601166207
# 3          91         100  1601166207
# 4          65          88  1601166182
# 6          82           0  1601166208
# 9          89          94  1601166208
# ..        ...         ...         ...
# 564        77          60  1601166264
# 565        88          90  1601166337
# 566        96         100  1601166337
# 568        65          13  1601166337
# 569        35           1  1601166338
#
# [393 rows x 9 columns]

# %%
S_hemi_df
# Out:
#                       City  Latitude  Longitude Country  Wind Speed  Max Temp  \
# 0                  honiara     -9.43     159.95      SB       12.75     87.80
# 1    san vicente de canete    -13.08     -76.38      PE        3.87     61.05
# 5                cape town    -33.93      18.42      ZA        4.70     46.40
# 7                  ushuaia    -54.80     -68.30      AR       20.80     37.40
# 8                 ambilobe    -13.20      49.05      MG        3.94     66.24
# ..                     ...       ...        ...     ...         ...       ...
# 550                gobabis    -22.45      18.97      NA        4.59     52.11
# 551            finschhafen     -6.60     147.87      PG        8.59     83.84
# 555             vila velha    -20.33     -40.29      BR       13.87     78.01
# 561           saint-pierre    -21.34      55.48      RE        8.05     68.00
# 567              maldonado    -34.67     -54.92      UY        4.70     62.60
#
#      Humidity  Cloudiness        Date
# 0          62          40  1601166207
# 1          80          12  1601166207
# 5          93          40  1601166083
# 7          74          40  1601166083
# 8          83           0  1601166208
# ..        ...         ...         ...
# 550        40           0  1601166333
# 551        69         100  1601166333
# 555        83           0  1601166334
# 561        60           0  1601166336
# 567        88          75  1601166110
#
# [177 rows x 9 columns]

# %% [markdown]
# ##### **Temperature (F) vs. Latitude in Northern Hemisphere - Linear Regression**

# %%
x_values = N_hemi_df["Latitude"]
y_values = N_hemi_df["Max Temp"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values,y_values)
regress_values = x_values * slope + intercept
line_eq = "y=" + str(round(slope,2)) + "x +" + str(round(intercept,2))
plt.scatter(x_values, y_values)
plt.plot(x_values, regress_values, "r-")
plt.annotate(line_eq, (0,10), fontsize=12, color="red")
plt.xlabel("Latitude (degrees)")
plt.ylabel("Temperature (F)")
plt.title("Temperature vs. Latitude in Northern Hemisphere")
plt.show()

# %% [markdown]
# ##### The plot above demonstrates a strong negative correlation between temperature and latitude in the Northern Hemisphere.

# %% [markdown]
# ##### **Temperature (F) vs. Latitude in Southern Hemisphere - Linear Regression**

# %%
x_values = S_hemi_df["Latitude"]
y_values = S_hemi_df["Max Temp"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values,y_values)
regress_values = x_values * slope + intercept
line_eq = "y=" + str(round(slope,2)) + "x +" + str(round(intercept,2))
plt.scatter(x_values, y_values)
plt.plot(x_values, regress_values, "r-")
plt.annotate(line_eq, (-50,38), fontsize=12, color="red")
plt.xlabel("Latitude (degrees)")
plt.ylabel("Temperature (F)")
plt.title("Temperature vs Latitude in Southern Hemisphere")
plt.show()

# %% [markdown]
# ##### The plot above demonstrates a strong positive correlation between temperature and latitude in the Southern Hemisphere.

# %% [markdown]
# #### **Humidity (%) vs. Latitude in Northern Hemisphere - Linear Regression**

# %%
x_values = N_hemi_df["Latitude"]
y_values = N_hemi_df["Humidity"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values,y_values)
regress_values = x_values * slope + intercept
line_eq = "y=" + str(round(slope,2)) + "x +" + str(round(intercept,2))
plt.scatter(x_values, y_values)
plt.plot(x_values, regress_values, "r-")
plt.annotate(line_eq,(0,0), fontsize = 12, color ='red')
plt.xlabel("Latitude (degrees)")
plt.ylabel("Humidity (%)")
plt.title("Humidity vs. Latitude in Northern Hemisphere")
plt.show()

# %% [markdown]
# ##### The plot above demonstrates almost no correlation between humidity and latitude in the Northern Hemisphere.

# %% [markdown]
# #### **Humidity (%) vs. Latitude in Southern Hemisphere - Linear Regression**

# %%
x_values = S_hemi_df["Latitude"]
y_values = S_hemi_df["Humidity"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values,y_values)
regress_values = x_values * slope + intercept
line_eq = "y=" + str(round(slope,2)) + "x +" + str(round(intercept,2))
plt.scatter(x_values, y_values)
plt.plot(x_values, regress_values, "r-")
plt.annotate(line_eq,(-55,15), fontsize = 12, color ='red')
plt.xlabel("Latitude (degrees)")
plt.ylabel("Humidity (%)")
plt.title("Humidity vs. Latitude in Southern Hemisphere")
plt.show()

# %% [markdown]
# ##### The plot above demonstrates a weakly positive or almost no correlation between humidity and latitude in the Southern Hemisphere.

# %% [markdown]
# #### **Cloudiness (%) vs. Latitude in Northern Hemisphere - Linear Regression**

# %%
x_values = N_hemi_df["Latitude"]
y_values = N_hemi_df["Cloudiness"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values,y_values)
regress_values = x_values * slope + intercept
line_eq = "y=" + str(round(slope,2)) + "x +" + str(round(intercept,2))
plt.scatter(x_values, y_values)
plt.plot(x_values, regress_values, "r-")
plt.annotate(line_eq,(55,50), fontsize = 12, color ='red')
plt.xlabel("Latitude (degrees)")
plt.ylabel("Cloudiness (%)")
plt.title(" Cloudiness vs. Latitude in Northern Hemisphere")
plt.show()

# %% [markdown]
# ##### The plot above demonstrates a weakly positive ot almost no correlation between cloudiness and latitude in the Northern Hemisphere.

# %% [markdown]
# #### **Cloudiness (%) vs. Latitude in Southern Hemisphere - Linear Regression**

# %%
x_values = S_hemi_df["Latitude"]
y_values = S_hemi_df["Cloudiness"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values,y_values)
regress_values = x_values * slope + intercept
line_eq = "y=" + str(round(slope,2)) + "x +" + str(round(intercept,2))
plt.scatter(x_values, y_values)
plt.plot(x_values, regress_values, "r-")
plt.annotate(line_eq,(-18,45), fontsize = 12, color ='red')
plt.xlabel("Latitude (degrees)")
plt.ylabel("Cloudiness (%)")
plt.title(" Cloudiness vs. Latitude in Southern Hemisphere")
plt.show()

# %% [markdown]
# ##### The plot above demonstrates almost no correlation between cloudiness and latitude in the Southern Hemisphere.

# %% [markdown]
# #### **Wind Speed (mph) vs. Latitude in Northern Hemisphere - Linear Regression**

# %%
x_values = N_hemi_df["Latitude"]
y_values = N_hemi_df["Wind Speed"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values,y_values)
regress_values = x_values * slope + intercept
line_eq = "y=" + str(round(slope,2)) + "x +" + str(round(intercept,2))
plt.scatter(x_values, y_values)
plt.plot(x_values, regress_values, "r-")
plt.annotate(line_eq,(50,28), fontsize = 12, color = "red")
plt.xlabel("Latitude (degrees)")
plt.ylabel("Wind Speed (mph)")
plt.title("Wind Speed vs. Latitude in Northern Hemisphere")
plt.show()

# %% [markdown]
# ##### The plot above demonstrates a weakly positive or almost no correlation between wind speed and latitude in the Northern Hemisphere.

# %% [markdown]
# #### **Wind Speed (mph) vs. Latitude in Southern Hemisphere - Linear Regression**

# %%
x_values = S_hemi_df["Latitude"]
y_values = S_hemi_df["Wind Speed"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values,y_values)
regress_values = x_values * slope + intercept
line_eq = "y=" + str(round(slope,2)) + "x +" + str(round(intercept,2))
plt.scatter(x_values, y_values)
plt.plot(x_values, regress_values, "r-")
plt.annotate(line_eq,(-18,28), fontsize = 12, color = "red")
plt.xlabel("Latitude (degrees)")
plt.ylabel("Wind Speed (mph)")
plt.title(" Wind Speed vs. Latitude in Southern Hemisphere")
plt.show()

# %% [markdown]
# ##### The plot above demonstrates a weakly negative or nearly no correlation between wind speed and latitude in the Southern Hemisphere.
